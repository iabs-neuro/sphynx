# %%
# !pip install natsort
# Out:
# Requirement already satisfied: natsort in c:\users\1\anaconda3\envs\deeplabcut\lib\site-packages (8.4.0)

# %%
import shutil
from glob import glob
import os
import re
from moviepy.editor import VideoFileClip, concatenate_videoclips
from natsort import natsorted

# паттерн для идентификатора мышесессии
pattern = r'[A-Z0-9]{3,4}_[A-z]{1,2}\d{2}_(\dD|\dT)(_\dT)?'

# укажи путь к папке с папками мышейсессий, добавь двойные слеши
root = 'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\'

# выбери структуру папок
# For Bonsai data
timestamps = glob(root + '*//*.csv')
# or For MiniscopeSoft data
#timestamps = glob(root + '*//*//*//Miniscope//timeStamps.csv')

print(f"Найдено всего {len(timestamps)} таймстемпов")
timestamps
# Out:
# Найдено всего 77 таймстемпов
# ['D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D14_2D_1T\\3DM_D14_2D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D14_3D_1T\\3DM_D14_3D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D14_4D_1T\\3DM_D14_4D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D14_5D_1T\\3DM_D14_5D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D14_6D_1T\\3DM_D14_6D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D14_6D_2T\\3DM_D14_6D_2T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D14_7D_1T\\3DM_D14_7D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D17_2D_1T\\3DM_D17_2D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D17_3D_1T\\3DM_D17_3D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D17_4D_1T\\3DM_D17_4D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D17_5D_1T\\3DM_D17_5D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D17_6D_1T\\3DM_D17_6D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_D17_7D_2T\\3DM_D17_7D_2T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_F26_1D_1T\\3DM_F26_1D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_F54_2D_1T\\3DM_F54_2D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_F54_3D_1T\\3DM_F54_3D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_F54_4D_1T\\3DM_F54_4D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_F54_5D_1T\\3DM_F54_5D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_F54_6D_1T\\3DM_F54_6D_1T_VTS_TS.csv',
#  'D:\\Projects\\Rogov\\3DM\\BehaviorSideData\\ALLMICE\\3DM_F54_7D_1T\\3DM_F54_7D_1T_VTS_TS.csv']

# %%
for tm in timestamps:
    splitted_path = os.path.normpath(tm).split(os.sep)

    # Поиск индекса каталога, совпадающего с шаблоном
    identifier_index = None
    for i, directory in enumerate(splitted_path):
        if re.match(pattern, directory):
            print(directory)
            identifier_index = i
            break
    
    # Вывод результата
    if identifier_index is not None:
        print(f"Идентификатор найден: '{splitted_path[identifier_index]}'")
    else:
        print("Идентификатор не найден в пути.")    
    
    mouse_name = splitted_path[identifier_index]
            
    # Считывает файлы и сортирует          
    avi_files = glob(os.path.dirname(tm) + '\\*.avi')    
    avi_files = natsorted(avi_files)
    print("\n".join(avi_files))
    
    # Объединяет видео и сохраняет
    clips = []
    for av in avi_files:            
        clips.append(VideoFileClip(av))
    result = concatenate_videoclips(clips)    
    
    # поменять для поведения 
    result.write_videofile(root + mouse_name + '.mp4')
# Out:
# 3DM_D14_2D_1T
# Идентификатор найден: '3DM_D14_2D_1T'
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_0.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_1.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_2.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_3.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_4.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_5.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_6.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_7.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_8.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_9.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_81.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_82.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_83.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_84.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_85.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_86.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_87.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_88.avi
# D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T\3DM_D14_2D_1T_89.avi
# Moviepy - Building video D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T.mp4.
# Moviepy - Writing video D:\Projects\Rogov\3DM\BehaviorSideData\ALLMICE\3DM_D14_2D_1T.mp4
# t:   0%|          | 227/89968 [00:00<05:22, 278.31it/s, now=None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 32
#      29 result = concatenate_videoclips(clips)
#      31 # поменять для поведения
# ---> 32 result.write_videofile(root + mouse_name + '.mp4')
#
# File <decorator-gen-73>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File <decorator-gen-72>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\decorators.py:135, in use_clip_fps_by_default(f, clip, *a, **k)
#     130 new_a = [fun(arg) if (name=='fps') else arg
#     131          for (arg, name) in zip(a, names)]
#     132 new_kw = {k: fun(v) if k=='fps' else v
#     133          for (k,v) in k.items()}
# --> 135 return f(clip, *new_a, **new_kw)
#
# File <decorator-gen-71>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\decorators.py:22, in convert_masks_to_RGB(f, clip, *a, **k)
#      20 if clip.ismask:
#      21     clip = clip.to_RGB()
# ---> 22 return f(clip, *a, **k)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\VideoClip.py:300, in VideoClip.write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     292 if make_audio:
#     293     self.audio.write_audiofile(audiofile, audio_fps,
#     294                                audio_nbytes, audio_bufsize,
#     295                                audio_codec, bitrate=audio_bitrate,
#     296                                write_logfile=write_logfile,
#     297                                verbose=verbose,
#     298                                logger=logger)
# --> 300 ffmpeg_write_video(self, filename, fps, codec,
#     301                    bitrate=bitrate,
#     302                    preset=preset,
#     303                    write_logfile=write_logfile,
#     304                    audiofile=audiofile,
#     305                    verbose=verbose, threads=threads,
#     306                    ffmpeg_params=ffmpeg_params,
#     307                    logger=logger)
#     309 if remove_temp and make_audio:
#     310     if os.path.exists(audiofile):
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\io\ffmpeg_writer.py:220, in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     213 with FFMPEG_VideoWriter(filename, clip.size, fps, codec = codec,
#     214                             preset=preset, bitrate=bitrate, logfile=logfile,
#     215                             audiofile=audiofile, threads=threads,
#     216                             ffmpeg_params=ffmpeg_params) as writer:
#     218     nframes = int(clip.duration*fps)
# --> 220     for t,frame in clip.iter_frames(logger=logger, with_times=True,
#     221                                     fps=fps, dtype="uint8"):
#     222         if withmask:
#     223             mask = (255*clip.mask.get_frame(t))
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\Clip.py:472, in Clip.iter_frames(self, fps, with_times, logger, dtype)
#     470 logger = proglog.default_bar_logger(logger)
#     471 for t in logger.iter_bar(t=np.arange(0, self.duration, 1.0/fps)):
# --> 472     frame = self.get_frame(t)
#     473     if (dtype is not None) and (frame.dtype != dtype):
#     474         frame = frame.astype(dtype)
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\compositing\concatenate.py:83, in concatenate_videoclips.<locals>.make_frame(t)
#      81 def make_frame(t):
#      82     i = max([i for i, e in enumerate(tt) if e <= t])
# ---> 83     return clips[i].get_frame(t - tt[i])
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\io\VideoFileClip.py:113, in VideoFileClip.__init__.<locals>.<lambda>(t)
#     109     self.mask.fps = self.fps
#     111 else:
# --> 113     self.make_frame = lambda t: self.reader.get_frame(t)
#     115 # Make a reader for the audio, if any.
#     116 if audio and self.reader.infos['audio_found']:
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:184, in FFMPEG_VideoReader.get_frame(self, t)
#     182 else:
#     183     self.skip_frames(pos-self.pos-1)
# --> 184 result = self.read_frame()
#     185 self.pos = pos
#     186 return result
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:120, in FFMPEG_VideoReader.read_frame(self)
#     117 w, h = self.size
#     118 nbytes= self.depth*w*h
# --> 120 s = self.proc.stdout.read(nbytes)
#     121 if len(s) != nbytes:
#     123     warnings.warn("Warning: in file %s, "%(self.filename)+
#     124            "%d bytes wanted but %d bytes read,"%(nbytes, len(s))+
#     125            "at frame %d/%d, at time %.02f/%.02f sec. "%(
#    (...)
#     129            "Using the last valid frame instead.",
#     130            UserWarning)
#
# KeyboardInterrupt:

# %%
## import shutil
# ToDo naming for 1 mode is wrong (only mouse id)

from glob import glob
import os
import re
from moviepy.editor import VideoFileClip, concatenate_videoclips
from natsort import natsorted

# Паттерн для идентификатора мышесессии вида "MSS_F01_1D_1T"
pattern = r'[A-Z]{3,4}_[A-Z]\d{2}_(\dD|\dT)(_\dT)?'

# Укажите путь к корневой папке с папками мышесессий
exp = 'HOS'
root = 'w:\\Projects\\HOS\\BehaviorData\\1_Raw\\'

# Выберите режим работы:
# 1 - Сшить все видео из одной папки
#mode = '1'
# 2 - Сшить все видео, относящиеся к одной мыши
mode = '1'

timestamps = glob(root + '*//*.csv')
print(f"Найдено всего {len(timestamps)} таймстемпов")
timestamps

if mode not in ["1", "2"]:
    print("Неверный выбор режима. Завершение программы.")
    exit()

# Множество для отслеживания обработанных идентификаторов мышей (только для режима 2)
processed_mice = set()

for tm in timestamps:
    splitted_path = os.path.normpath(tm).split(os.sep)

    # Поиск идентификатора мышесессии
    identifier_index = None
    for i, directory in enumerate(splitted_path):
        if re.match(pattern, directory):
            identifier_index = i
            break
    
    if identifier_index is None:
        print(f"Идентификатор не найден в пути: {tm}")
        continue
    
    mouse_session = splitted_path[identifier_index]
    
    # Извлекаем идентификатор мыши (например, F04 из MSS_F04_1D_1T)
    mouse_id_match = re.search(r'_([A-Z]\d{2})_', mouse_session)
    if not mouse_id_match:
        print(f"Не удалось извлечь идентификатор мыши из: {mouse_session}")
        continue
    mouse_id = mouse_id_match.group(1)

    # Проверка для режима 2: пропускаем уже обработанных мышей
    if mode == "2" and mouse_id in processed_mice:
        continue

    # Получение списка видео в зависимости от режима
    avi_files = []
    if mode == "1":  # Режим 1: Сшить видео из одной папки
        avi_files = glob(os.path.dirname(tm) + '\\*.avi')
    elif mode == "2":  # Режим 2: Сшить все видео по идентификатору мыши
        avi_files = glob(root + '**/*.avi', recursive=True)
        avi_files = [file for file in avi_files if f"_{mouse_id}_" in os.path.basename(file)]
        processed_mice.add(mouse_id)  # Отмечаем идентификатор как обработанный
    
    if not avi_files:
        print(f"Видео не найдены для {mouse_id}. Пропуск.")
        continue

    # Сортировка файлов в алфавитном порядке
    avi_files = natsorted(avi_files)
    print(f"Найдено {len(avi_files)} видео для {mouse_id}:")
    print("\n".join(avi_files))

    # Объединение видео и сохранение
    clips = []
    for av in avi_files:
        clips.append(VideoFileClip(av))
    result = concatenate_videoclips(clips)

    # Сохранение результата
    output_file = os.path.join(root, f"{exp}_{mouse_id}.mp4")
    result.write_videofile(output_file)
    print(f"Видео сохранено: {output_file}")
# Out:
# Найдено всего 40 таймстемпов
# Найдено 19 видео для D01:
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_0.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_1.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_2.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_3.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_4.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_5.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_6.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_7.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_8.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_9.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_10.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_11.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_12.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_13.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_14.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_15.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_16.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_17.avi
# w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01_1D_1T\HOS_D01_1D_1T_18.avi
#
# t:   7%|▋         | 6685/89991 [01:48<15:12, 91.26it/s, now=None]
#                                                                  [A
# t:   7%|▋         | 6685/89991 [01:48<15:12, 91.26it/s, now=None]
# t:   1%|          | 202/18001 [00:11<03:42, 79.88it/s, now=None]
# Moviepy - Building video w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01.mp4.
# Moviepy - Writing video w:\Projects\HOS\BehaviorData\1_Raw\HOS_D01.mp4
# t:   0%|          | 0/18001 [00:00<?, ?it/s, now=None]
#
# t:   0%|          | 7/18001 [00:00<04:26, 67.49it/s, now=None]
#
# t:   0%|          | 21/18001 [00:00<02:50, 105.32it/s, now=None]
#
# t:   0%|          | 35/18001 [00:00<02:30, 119.14it/s, now=None]
#
# t:   0%|          | 48/18001 [00:00<03:38, 82.33it/s, now=None]
#
# t:   0%|          | 58/18001 [00:00<03:30, 85.27it/s, now=None]
#
# t:   0%|          | 70/18001 [00:00<03:13, 92.52it/s, now=None]
#
# t:   0%|          | 80/18001 [00:00<03:22, 88.35it/s, now=None]
#
# t:   0%|          | 90/18001 [00:01<03:24, 87.48it/s, now=None]
#
# t:   1%|          | 100/18001 [00:01<03:20, 89.38it/s, now=None]
#
# t:   1%|          | 110/18001 [00:01<03:15, 91.54it/s, now=None]
#
# t:   1%|          | 120/18001 [00:01<03:15, 91.57it/s, now=None]
# t:   1%|          | 202/18001 [00:12<03:42, 79.88it/s, now=None]
#
# t:   1%|          | 130/18001 [00:01<03:18, 89.82it/s, now=None]
#
# t:   1%|          | 140/18001 [00:01<03:17, 90.32it/s, now=None]
#
# t:   1%|          | 150/18001 [00:01<03:16, 90.81it/s, now=None]
#
# t:   1%|          | 160/18001 [00:01<03:17, 90.42it/s, now=None]
#
# t:   1%|          | 170/18001 [00:01<03:23, 87.67it/s, now=None]
#
# t:   1%|          | 179/18001 [00:01<03:23, 87.74it/s, now=None]
#
# t:   1%|          | 188/18001 [00:02<03:29, 84.85it/s, now=None]
#
# t:   1%|          | 197/18001 [00:02<03:31, 84.10it/s, now=None]
#
# t:   1%|          | 206/18001 [00:02<03:32, 83.81it/s, now=None]
#
# t:   1%|          | 215/18001 [00:02<03:29, 84.78it/s, now=None]
#
# t:   1%|▏         | 226/18001 [00:02<03:15, 90.93it/s, now=None]
#
# t:   1%|▏         | 236/18001 [00:02<03:20, 88.69it/s, now=None]
#
# t:   1%|▏         | 245/18001 [00:02<03:19, 88.89it/s, now=None]
#
# t:   1%|▏         | 255/18001 [00:02<03:15, 90.63it/s, now=None]
#
# t:   1%|▏         | 265/18001 [00:02<03:14, 91.37it/s, now=None]
#
# t:   2%|▏         | 275/18001 [00:03<03:10, 92.83it/s, now=None]
#
# t:   2%|▏         | 285/18001 [00:03<03:06, 94.82it/s, now=None]
#
# t:   2%|▏         | 296/18001 [00:03<03:00, 98.30it/s, now=None]
#
# t:   2%|▏         | 306/18001 [00:03<03:04, 95.65it/s, now=None]
#
# t:   2%|▏         | 316/18001 [00:03<03:06, 94.92it/s, now=None]
#
# t:   2%|▏         | 326/18001 [00:03<03:22, 87.19it/s, now=None]
#
# t:   2%|▏         | 336/18001 [00:03<03:15, 90.19it/s, now=None]
#
# t:   2%|▏         | 347/18001 [00:03<03:08, 93.67it/s, now=None]
#
# t:   2%|▏         | 357/18001 [00:03<03:11, 92.01it/s, now=None]
#
# t:   2%|▏         | 367/18001 [00:04<03:13, 90.98it/s, now=None]
#
# t:   4%|▍         | 742/18001 [00:08<03:19, 86.40it/s, now=None]
#
# t:   4%|▍         | 751/18001 [00:08<03:23, 84.95it/s, now=None]
#
# t:   4%|▍         | 760/18001 [00:08<03:25, 83.78it/s, now=None]
#
# t:   4%|▍         | 769/18001 [00:08<03:25, 83.88it/s, now=None]
#
# t:   4%|▍         | 779/18001 [00:08<03:18, 86.67it/s, now=None]
#
# t:   4%|▍         | 788/18001 [00:08<03:21, 85.57it/s, now=None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 85
#      83 # Сохранение результата
#      84 output_file = os.path.join(root, f"{exp}_{mouse_id}.mp4")
# ---> 85 result.write_videofile(output_file)
#      86 print(f"Видео сохранено: {output_file}")
#
# File <decorator-gen-73>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File <decorator-gen-72>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\decorators.py:135, in use_clip_fps_by_default(f, clip, *a, **k)
#     130 new_a = [fun(arg) if (name=='fps') else arg
#     131          for (arg, name) in zip(a, names)]
#     132 new_kw = {k: fun(v) if k=='fps' else v
#     133          for (k,v) in k.items()}
# --> 135 return f(clip, *new_a, **new_kw)
#
# File <decorator-gen-71>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\decorators.py:22, in convert_masks_to_RGB(f, clip, *a, **k)
#      20 if clip.ismask:
#      21     clip = clip.to_RGB()
# ---> 22 return f(clip, *a, **k)
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\VideoClip.py:300, in VideoClip.write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     292 if make_audio:
#     293     self.audio.write_audiofile(audiofile, audio_fps,
#     294                                audio_nbytes, audio_bufsize,
#     295                                audio_codec, bitrate=audio_bitrate,
#     296                                write_logfile=write_logfile,
#     297                                verbose=verbose,
#     298                                logger=logger)
# --> 300 ffmpeg_write_video(self, filename, fps, codec,
#     301                    bitrate=bitrate,
#     302                    preset=preset,
#     303                    write_logfile=write_logfile,
#     304                    audiofile=audiofile,
#     305                    verbose=verbose, threads=threads,
#     306                    ffmpeg_params=ffmpeg_params,
#     307                    logger=logger)
#     309 if remove_temp and make_audio:
#     310     if os.path.exists(audiofile):
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\io\ffmpeg_writer.py:228, in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     225                 mask = mask.astype("uint8")
#     226             frame = np.dstack([frame,mask])
# --> 228         writer.write_frame(frame)
#     230 if write_logfile:
#     231     logfile.close()
#
# File ~\anaconda3\envs\caiman2\lib\site-packages\moviepy\video\io\ffmpeg_writer.py:136, in FFMPEG_VideoWriter.write_frame(self, img_array)
#     134 try:
#     135     if PY3:
# --> 136        self.proc.stdin.write(img_array.tobytes())
#     137     else:
#     138        self.proc.stdin.write(img_array.tostring())
#
# KeyboardInterrupt:
# t:   4%|▍         | 795/18001 [00:21<03:21, 85.57it/s, now=None]
